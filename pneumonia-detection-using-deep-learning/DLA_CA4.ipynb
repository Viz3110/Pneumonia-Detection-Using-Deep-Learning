# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("GPU device name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "Not detected")
# Out:
# CUDA available: True
# GPU device name: NVIDIA GeForce RTX 4060 Laptop GPU

# %%
pip install fastai
# Out:
# Collecting fastai
#   Using cached fastai-2.8.2-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: pip in d:\anaconda3\envs\torch-gpu\lib\site-packages (from fastai) (25.1)
# Requirement already satisfied: packaging in d:\anaconda3\envs\torch-gpu\lib\site-packages (from fastai) (24.2)
# Collecting fastdownload<2,>=0.0.5 (from fastai)
#   Using cached fastdownload-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Collecting fastcore<1.9,>=1.8.0 (from fastai)
#   Using cached fastcore-1.8.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting fasttransform>=0.0.2 (from fastai)
#   Using cached fasttransform-0.0.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: torchvision>=0.11 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from fastai) (0.20.1+cu121)
# Collecting matplotlib (from fastai)
#   Downloading matplotlib-3.10.3-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting pandas (from fastai)
#   Downloading pandas-2.3.1-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: requests in d:\anaconda3\envs\torch-gpu\lib\site-packages (from fastai) (2.32.4)
# Requirement already satisfied: pyyaml in d:\anaconda3\envs\torch-gpu\lib\site-packages (from fastai) (6.0.2)
# Collecting fastprogress>=0.2.4 (from fastai)
#   Using cached fastprogress-1.0.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pillow>=9.0.0 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from fastai) (11.0.0)
# Collecting scikit-learn (from fastai)
#   Downloading scikit_learn-1.7.1-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting scipy (from fastai)
#   Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting spacy<4 (from fastai)
#   Downloading spacy-3.8.7-cp310-cp310-win_amd64.whl.metadata (28 kB)
# Collecting plum-dispatch (from fastai)
#   Using cached plum_dispatch-2.5.7-py3-none-any.whl.metadata (7.5 kB)
# Collecting cloudpickle (from fastai)
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: torch<2.8,>=1.10 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from fastai) (2.5.1+cu121)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy<4->fastai)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy<4->fastai)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy<4->fastai)
#   Downloading murmurhash-1.0.13-cp310-cp310-win_amd64.whl.metadata (2.2 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy<4->fastai)
#   Downloading cymem-2.0.11-cp310-cp310-win_amd64.whl.metadata (8.8 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy<4->fastai)
#   Downloading preshed-3.0.10-cp310-cp310-win_amd64.whl.metadata (2.5 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy<4->fastai)
#   Downloading thinc-8.3.6-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy<4->fastai)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy<4->fastai)
#   Downloading srsly-2.5.1-cp310-cp310-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy<4->fastai)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy<4->fastai)
#   Using cached weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy<4->fastai)
#   Downloading typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Collecting tqdm<5.0.0,>=4.38.0 (from spacy<4->fastai)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: numpy>=1.19.0 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from spacy<4->fastai) (2.1.2)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy<4->fastai)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: jinja2 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from spacy<4->fastai) (3.1.4)
# Requirement already satisfied: setuptools in d:\anaconda3\envs\torch-gpu\lib\site-packages (from spacy<4->fastai) (78.1.1)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy<4->fastai)
#   Using cached langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy<4->fastai)
#   Using cached language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai)
#   Downloading pydantic_core-2.33.2-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (4.12.2)
# Collecting typing-inspection>=0.4.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from requests->fastai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from requests->fastai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from requests->fastai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from requests->fastai) (2025.7.14)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy<4->fastai)
#   Downloading blis-1.3.0-cp310-cp310-win_amd64.whl.metadata (7.6 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy<4->fastai)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in d:\anaconda3\envs\torch-gpu\lib\site-packages (from torch<2.8,>=1.10->fastai) (3.13.1)
# Requirement already satisfied: networkx in d:\anaconda3\envs\torch-gpu\lib\site-packages (from torch<2.8,>=1.10->fastai) (3.3)
# Requirement already satisfied: fsspec in d:\anaconda3\envs\torch-gpu\lib\site-packages (from torch<2.8,>=1.10->fastai) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from torch<2.8,>=1.10->fastai) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from sympy==1.13.1->torch<2.8,>=1.10->fastai) (1.3.0)
# Requirement already satisfied: colorama in d:\anaconda3\envs\torch-gpu\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4->fastai) (0.4.6)
# Collecting click>=8.0.0 (from typer<1.0.0,>=0.3.0->spacy<4->fastai)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy<4->fastai)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0.0,>=0.3.0->spacy<4->fastai)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy<4->fastai)
#   Using cached cloudpathlib-0.21.1-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy<4->fastai)
#   Using cached smart_open-7.3.0.post1-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4->fastai)
#   Downloading wrapt-1.17.2-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Collecting marisa-trie>=1.1.0 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4->fastai)
#   Downloading marisa_trie-1.2.1-cp310-cp310-win_amd64.whl.metadata (9.3 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from jinja2->spacy<4->fastai) (2.1.5)
# Collecting contourpy>=1.0.1 (from matplotlib->fastai)
#   Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->fastai)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->fastai)
#   Downloading fonttools-4.59.0-cp310-cp310-win_amd64.whl.metadata (110 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->fastai)
#   Downloading kiwisolver-1.4.8-cp310-cp310-win_amd64.whl.metadata (6.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->fastai)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib->fastai) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\torch-gpu\lib\site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.17.0)
# Collecting pytz>=2020.1 (from pandas->fastai)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->fastai)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting beartype>=0.16.2 (from plum-dispatch->fastai)
#   Using cached beartype-0.21.0-py3-none-any.whl.metadata (33 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->fastai)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->fastai)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached fastai-2.8.2-py3-none-any.whl (235 kB)
# Using cached fastcore-1.8.7-py3-none-any.whl (79 kB)
# Using cached fastdownload-0.0.7-py3-none-any.whl (12 kB)
# Downloading spacy-3.8.7-cp310-cp310-win_amd64.whl (14.9 MB)
#    ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#    ------- -------------------------------- 2.9/14.9 MB 15.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.6/14.9 MB 16.8 MB/s eta 0:00:01
#    -------------------------- ------------- 10.0/14.9 MB 17.3 MB/s eta 0:00:01
#    ------------------------------------- -- 13.9/14.9 MB 17.5 MB/s eta 0:00:01
#    ---------------------------------------- 14.9/14.9 MB 17.1 MB/s eta 0:00:00
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.11-cp310-cp310-win_amd64.whl (39 kB)
# Using cached langcodes-3.5.0-py3-none-any.whl (182 kB)
# Downloading murmurhash-1.0.13-cp310-cp310-win_amd64.whl (24 kB)
# Downloading preshed-3.0.10-cp310-cp310-win_amd64.whl (117 kB)
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp310-cp310-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 13.5 MB/s eta 0:00:00
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.1-cp310-cp310-win_amd64.whl (632 kB)
#    ---------------------------------------- 0.0/632.3 kB ? eta -:--:--
#    --------------------------------------- 632.3/632.3 kB 23.1 MB/s eta 0:00:00
# Downloading thinc-8.3.6-cp310-cp310-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 16.1 MB/s eta 0:00:00
# Downloading blis-1.3.0-cp310-cp310-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ----------------------- ---------------- 3.7/6.2 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 18.3 MB/s eta 0:00:00
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typer-0.16.0-py3-none-any.whl (46 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached weasel-0.4.1-py3-none-any.whl (50 kB)
# Using cached cloudpathlib-0.21.1-py3-none-any.whl (52 kB)
# Using cached smart_open-7.3.0.post1-py3-none-any.whl (61 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Using cached fastprogress-1.0.3-py3-none-any.whl (12 kB)
# Using cached fasttransform-0.0.2-py3-none-any.whl (14 kB)
# Using cached language_data-1.3.0-py3-none-any.whl (5.4 MB)
# Downloading marisa_trie-1.2.1-cp310-cp310-win_amd64.whl (151 kB)
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading matplotlib-3.10.3-cp310-cp310-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------------------ --------------------- 3.7/8.1 MB 18.1 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 18.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 17.2 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.0-cp310-cp310-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 14.3 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading pandas-2.3.1-cp310-cp310-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ------------ --------------------------- 3.4/11.3 MB 18.3 MB/s eta 0:00:01
#    ------------------------- -------------- 7.3/11.3 MB 18.1 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.3 MB 18.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 17.7 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached plum_dispatch-2.5.7-py3-none-any.whl (42 kB)
# Using cached beartype-0.21.0-py3-none-any.whl (1.2 MB)
# Downloading scikit_learn-1.7.1-cp310-cp310-win_amd64.whl (8.9 MB)
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ---------------- ----------------------- 3.7/8.9 MB 18.1 MB/s eta 0:00:01
#    -------------------------------- ------- 7.3/8.9 MB 18.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.9/8.9 MB 17.8 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    --- ------------------------------------ 3.7/41.3 MB 18.2 MB/s eta 0:00:03
#    ------- -------------------------------- 7.3/41.3 MB 18.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 11.0/41.3 MB 18.1 MB/s eta 0:00:02
#    -------------- ------------------------- 14.7/41.3 MB 18.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 18.4/41.3 MB 18.1 MB/s eta 0:00:02
#    -------------------- ------------------- 21.5/41.3 MB 17.9 MB/s eta 0:00:02
#    ------------------------ --------------- 25.2/41.3 MB 17.9 MB/s eta 0:00:01
#    --------------------------- ------------ 28.8/41.3 MB 17.9 MB/s eta 0:00:01
#    ------------------------------- -------- 32.5/41.3 MB 18.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 36.2/41.3 MB 18.0 MB/s eta 0:00:01
#    -------------------------------------- - 39.6/41.3 MB 17.8 MB/s eta 0:00:01
#    ---------------------------------------- 41.3/41.3 MB 17.3 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading wrapt-1.17.2-cp310-cp310-win_amd64.whl (38 kB)
# Installing collected packages: pytz, cymem, wrapt, wasabi, tzdata, typing-inspection, tqdm, threadpoolctl, spacy-loggers, spacy-legacy, shellingham, scipy, pyparsing, pydantic-core, murmurhash, mdurl, marisa-trie, kiwisolver, joblib, fonttools, fastprogress, fastcore, cycler, contourpy, cloudpickle, cloudpathlib, click, catalogue, blis, beartype, annotated-types, srsly, smart-open, scikit-learn, pydantic, preshed, pandas, matplotlib, markdown-it-py, language-data, fastdownload, rich, langcodes, confection, typer, thinc, plum-dispatch, weasel, fasttransform, spacy, fastai
#
#    ----------------------------------------  0/51 [pytz]
#    - --------------------------------------  2/51 [wrapt]
#    --- ------------------------------------  4/51 [tzdata]
#    --- ------------------------------------  4/51 [tzdata]
#    ---- -----------------------------------  6/51 [tqdm]
#    ------- -------------------------------- 10/51 [shellingham]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    -------- ------------------------------- 11/51 [scipy]
#    ---------- ----------------------------- 14/51 [murmurhash]
#    -------------- ------------------------- 18/51 [joblib]
#    -------------- ------------------------- 19/51 [fonttools]
#    -------------- ------------------------- 19/51 [fonttools]
#    -------------- ------------------------- 19/51 [fonttools]
#    -------------- ------------------------- 19/51 [fonttools]
#    -------------- ------------------------- 19/51 [fonttools]
#    -------------- ------------------------- 19/51 [fonttools]
#    --------------- ------------------------ 20/51 [fastprogress]
#    ------------------ --------------------- 24/51 [cloudpickle]
#    --------------------- ------------------ 28/51 [blis]
#    ---------------------- ----------------- 29/51 [beartype]
#    ---------------------- ----------------- 29/51 [beartype]
#    ---------------------- ----------------- 29/51 [beartype]
#    ---------------------- ----------------- 29/51 [beartype]
#    ------------------------ --------------- 31/51 [srsly]
#    ------------------------ --------------- 31/51 [srsly]
#    ------------------------- -------------- 32/51 [smart-open]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    ------------------------- -------------- 33/51 [scikit-learn]
#    -------------------------- ------------- 34/51 [pydantic]
#    -------------------------- ------------- 34/51 [pydantic]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ---------------------------- ----------- 36/51 [pandas]
#    ----------------------------- ---------- 37/51 [matplotlib]
#    ----------------------------- ---------- 37/51 [matplotlib]
#    ----------------------------- ---------- 37/51 [matplotlib]
#    ----------------------------- ---------- 37/51 [matplotlib]
#    ----------------------------- ---------- 37/51 [matplotlib]
#    ----------------------------- ---------- 37/51 [matplotlib]
#    ----------------------------- ---------- 37/51 [matplotlib]
#    ----------------------------- ---------- 37/51 [matplotlib]
#    ----------------------------- ---------- 37/51 [matplotlib]
#    ----------------------------- ---------- 37/51 [matplotlib]
#    ----------------------------- ---------- 38/51 [markdown-it-py]
#    ------------------------------ --------- 39/51 [language-data]
#    ------------------------------ --------- 39/51 [language-data]
#    ------------------------------ --------- 39/51 [language-data]
#    -------------------------------- ------- 41/51 [rich]
#    -------------------------------- ------- 41/51 [rich]
#    ----------------------------------- ---- 45/51 [thinc]
#    ----------------------------------- ---- 45/51 [thinc]
#    ----------------------------------- ---- 45/51 [thinc]
#    -------------------------------------- - 49/51 [spacy]
#    -------------------------------------- - 49/51 [spacy]
#    -------------------------------------- - 49/51 [spacy]
#    -------------------------------------- - 49/51 [spacy]
#    -------------------------------------- - 49/51 [spacy]
#    -------------------------------------- - 49/51 [spacy]
#    -------------------------------------- - 49/51 [spacy]
#    -------------------------------------- - 49/51 [spacy]
#    -------------------------------------- - 49/51 [spacy]
#    -------------------------------------- - 49/51 [spacy]
#    -------------------------------------- - 49/51 [spacy]
#    -------------------------------------- - 49/51 [spacy]
#    ---------------------------------------  50/51 [fastai]
#    ---------------------------------------  50/51 [fastai]
#    ---------------------------------------- 51/51 [fastai]
#
# Successfully installed annotated-types-0.7.0 beartype-0.21.0 blis-1.3.0 catalogue-2.0.10 click-8.2.1 cloudpathlib-0.21.1 cloudpickle-3.1.1 confection-0.1.5 contourpy-1.3.2 cycler-0.12.1 cymem-2.0.11 fastai-2.8.2 fastcore-1.8.7 fastdownload-0.0.7 fastprogress-1.0.3 fasttransform-0.0.2 fonttools-4.59.0 joblib-1.5.1 kiwisolver-1.4.8 langcodes-3.5.0 language-data-1.3.0 marisa-trie-1.2.1 markdown-it-py-3.0.0 matplotlib-3.10.3 mdurl-0.1.2 murmurhash-1.0.13 pandas-2.3.1 plum-dispatch-2.5.7 preshed-3.0.10 pydantic-2.11.7 pydantic-core-2.33.2 pyparsing-3.2.3 pytz-2025.2 rich-14.1.0 scikit-learn-1.7.1 scipy-1.15.3 shellingham-1.5.4 smart-open-7.3.0.post1 spacy-3.8.7 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.1 thinc-8.3.6 threadpoolctl-3.6.0 tqdm-4.67.1 typer-0.16.0 typing-inspection-0.4.1 tzdata-2025.2 wasabi-1.1.3 weasel-0.4.1 wrapt-1.17.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from fastai.vision.all import *
import numpy as np
import pandas as pd
import os

# %%
from pathlib import Path
path = Path("D:\College\Year3 Term4\Deep Learning Applications\Assignment\CA4\Dataset\chest_xray")
path.ls()
# Out:
# (#5) [Path('D:/College/Year3 Term4/Deep Learning Applications/Assignment/CA4/Dataset/chest_xray/chest_xray'),Path('D:/College/Year3 Term4/Deep Learning Applications/Assignment/CA4/Dataset/chest_xray/test'),Path('D:/College/Year3 Term4/Deep Learning Applications/Assignment/CA4/Dataset/chest_xray/train'),Path('D:/College/Year3 Term4/Deep Learning Applications/Assignment/CA4/Dataset/chest_xray/val'),Path('D:/College/Year3 Term4/Deep Learning Applications/Assignment/CA4/Dataset/chest_xray/__MACOSX')]

# %%
dls = ImageDataLoaders.from_folder(
    path/'train',
    valid_pct=0.2,
    item_tfms=Resize(224),
    batch_tfms=aug_transforms(),
    seed=42
)

dls.show_batch(max_n=9, figsize=(6,6))

# %%
learn = cnn_learner(dls, resnet50, metrics=accuracy)
learn.fine_tune(4)
# Out:
# D:\anaconda3\envs\torch-gpu\lib\site-packages\fastai\vision\learner.py:303: UserWarning: `cnn_learner` has been renamed to `vision_learner` -- please update your code
#   warn("`cnn_learner` has been renamed to `vision_learner` -- please update your code")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.528530</td>
#       <td>0.329620</td>
#       <td>0.903164</td>
#       <td>01:30</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.246728</td>
#       <td>0.160295</td>
#       <td>0.960690</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.185738</td>
#       <td>0.146613</td>
#       <td>0.957814</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.130674</td>
#       <td>0.107357</td>
#       <td>0.961649</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.124050</td>
#       <td>0.097096</td>
#       <td>0.964525</td>
#       <td>01:29</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(5,5))
interp.plot_top_losses(5, nrows=1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
img = PILImage.create(r"D:\College\Year3 Term4\Deep Learning Applications\Assignment\CA4\Dataset\chest_xray\test\NORMAL\IM-0001-0001.jpeg")
pred_class, pred_idx, outputs = learn.predict(img)
print(f"Prediction: {pred_class}")
img.show()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: NORMAL
# <Axes: >
